# %%
import pandas as pd
from IPython.display import display

df = pd.read_csv("gsm8k_llama3.1-8b-instant.csv")
display(df)

accuracy = df["is_correct"].mean()

print("Accuracy:", accuracy)
# Out:
#    question_id                 model  correct_answer  model_answer  \
# 0            0  llama-3.1-8b-instant              18          18.0
# 1            1  llama-3.1-8b-instant               3           3.0
# 2            2  llama-3.1-8b-instant           70000           0.0
# 3            3  llama-3.1-8b-instant             540         540.0
# 4            4  llama-3.1-8b-instant              20          20.0
# 5            5  llama-3.1-8b-instant              64          64.0
# 6            6  llama-3.1-8b-instant             260         260.0
# 7            7  llama-3.1-8b-instant             160         140.0
# 8            8  llama-3.1-8b-instant              45         315.0
# 9            9  llama-3.1-8b-instant             460         460.0
#
#    is_correct                   timestamp
# 0       False  2026-03-01 09:48:56.503461
# 1        True  2026-03-01 09:48:56.689760
# 2       False  2026-03-01 09:48:57.125370
# 3        True  2026-03-01 09:48:57.258753
# ...

# %%
df = pd.read_csv("gsm8k_llama3.3-70b-versatile.csv")
display(df)
accuracy = df["is_correct"].mean()

print("Accuracy:", accuracy)
# Out:
#    question_id                    model  correct_answer  model_answer  \
# 0            0  llama-3.3-70b-versatile              18          28.0
# 1            1  llama-3.3-70b-versatile               3           3.0
# 2            2  llama-3.3-70b-versatile           70000           0.0
# 3            3  llama-3.3-70b-versatile             540         540.0
# 4            4  llama-3.3-70b-versatile              20          10.0
# 5            5  llama-3.3-70b-versatile              64          64.0
# 6            6  llama-3.3-70b-versatile             260          72.0
# 7            7  llama-3.3-70b-versatile             160         160.0
# 8            8  llama-3.3-70b-versatile              45          45.0
# 9            9  llama-3.3-70b-versatile             460         475.0
#
#    is_correct                   timestamp
# 0       False  2026-03-01 10:06:46.446760
# 1        True  2026-03-01 10:06:46.551894
# 2       False  2026-03-01 10:06:46.657311
# ...

# %%
df = pd.read_csv("gsm8k_openai_gpt-oss-120b.csv")
display(df)

accuracy = df["is_correct"].mean()

print("Accuracy:", accuracy)
# Out:
#    question_id                model  correct_answer  model_answer  is_correct  \
# 0            0  openai/gpt-oss-120b              18            18        True
# 1            1  openai/gpt-oss-120b               3             3        True
# 2            2  openai/gpt-oss-120b           70000         70000        True
# 3            3  openai/gpt-oss-120b             540           540        True
# 4            4  openai/gpt-oss-120b              20            20        True
# 5            5  openai/gpt-oss-120b              64            64        True
# 6            6  openai/gpt-oss-120b             260           260        True
# 7            7  openai/gpt-oss-120b             160           160        True
# 8            8  openai/gpt-oss-120b              45            45        True
# 9            9  openai/gpt-oss-120b             460           460        True
#
#                     timestamp
# 0  2026-03-01 16:38:04.501176
# 1  2026-03-01 16:38:04.755224
# ...

# %%
results_df = pd.read_csv("rubric_gsm8k_openai_gpt-oss-120b.csv")
display(results_df)
# Out:
#    question_id                model  score  \
# 0            0  openai/gpt-oss-120b     10
# 1            1  openai/gpt-oss-120b     10
# 2            2  openai/gpt-oss-120b     10
# 3            3  openai/gpt-oss-120b     10
# 4            4  openai/gpt-oss-120b     10
# 5            5  openai/gpt-oss-120b     10
# 6            6  openai/gpt-oss-120b     10
# 7            7  openai/gpt-oss-120b     10
# 8            8  openai/gpt-oss-120b     10
# 9            9  openai/gpt-oss-120b     10
#
#                                                                                                                                                                                    feedback  \
# 0                                                                                                    Correct answer and correct arithmetic reasoning; solution is clear and well-explained.
# ...

# %%
results_df = pd.read_csv("rubric_gsm8k_llama-3.1-8b-instant.csv")
display(results_df)
# Out:
#    question_id                 model  score  \
# 0            0  llama-3.1-8b-instant      8
# 1            1  llama-3.1-8b-instant      6
# 2            2  llama-3.1-8b-instant      9
# 3            3  llama-3.1-8b-instant      9
# 4            4  llama-3.1-8b-instant      9
# 5            5  llama-3.1-8b-instant      9
# 6            6  llama-3.1-8b-instant     10
# 7            7  llama-3.1-8b-instant      9
# 8            8  llama-3.1-8b-instant      9
# 9            9  llama-3.1-8b-instant      9
#
#                                                                                                                                                                                                                                                                                                                          feedback  \
# ...

# %%
results_df = pd.read_csv("rubric_gsm8k_llama-3.3-70b-versatile.csv")
display(results_df)
# Out:
#    question_id                    model  score  \
# 0            0  llama-3.3-70b-versatile     10
# 1            1  llama-3.3-70b-versatile     10
# 2            2  llama-3.3-70b-versatile     10
# 3            3  llama-3.3-70b-versatile     10
# 4            4  llama-3.3-70b-versatile     10
# 5            5  llama-3.3-70b-versatile     10
# 6            6  llama-3.3-70b-versatile     10
# 7            7  llama-3.3-70b-versatile     10
# 8            8  llama-3.3-70b-versatile     10
# 9            9  llama-3.3-70b-versatile     10
#
#                                                                                                                                                                            feedback  \
# 0                                                The student provided a correct final answer with clear and logical reasoning steps, explaining the calculation process thoroughly.
# ...
